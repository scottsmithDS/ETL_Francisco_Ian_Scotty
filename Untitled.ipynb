# %%
import requests
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import re
import csv
import numpy as np
pd.set_option('display.max_columns', None)
# importss above

newvariablesIntl = pd.read_csv('IntlIDs.csv')
newvariablesIntl = pd.DataFrame(newvariablesIntl)
newvariablesIntl = newvariablesIntl.drop("Unnamed: 0", axis=1, inplace = False)
newvariablesPeru = pd.read_csv('PeruIDs.csv')
newvariablesPeru = pd.DataFrame(newvariablesPeru)
newvariablesPeru = newvariablesPeru.drop("Unnamed: 0", axis=1, inplace = False)
newvariablesEcuador = pd.read_csv('EcuadorIDs.csv')
newvariablesEcuador = pd.DataFrame(newvariablesEcuador)
newvariablesEcuador = newvariablesEcuador.drop("Unnamed: 0", axis=1, inplace = False)
newvariablesMexB = pd.read_csv('MexBeerIDs.csv')
newvariablesMexB = pd.DataFrame(newvariablesMexB)
newvariablesMexB = newvariablesMexB.drop("Unnamed: 0", axis=1, inplace = False)

for value in newvariablesIntl['ID']:
    change = {value: "/submissions/" + str(value) + "/webview"}
    newvariablesIntl.replace(change, inplace = True)
    newvariablesIntl.dropna(how ='all', inplace = True)
for value in newvariablesPeru['ID']:
    change = {value: "/submissions/" + str(value) + "/webview"}
    newvariablesPeru.replace(change, inplace = True)
    newvariablesPeru.dropna(how ='all', inplace = True)
for value in newvariablesEcuador['ID']:
    change = {value: "/submissions/" + str(value) + "/webview"}
    newvariablesEcuador.replace(change, inplace = True)
    newvariablesEcuador.dropna(how ='all', inplace = True)
for value in newvariablesMexB['ID']:
    change = {value: "/submissions/" + str(value) + "/webview"}
    newvariablesMexB.replace(change, inplace = True)
    newvariablesMexB.dropna(how ='all', inplace = True)

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36'
}

login_data = {
    'utf8': '✓',
    'user[email]': 'scottys@maxianet.com',
    'user[password]': '1Sandiego!',
    'user[remember_me]': '0'
    
}
imageurls = []
times = []

timecheck_in = []
    
full_path = "hello"+'.jpg'
timerss = []

timedf = {}
lat = {}
lng = {}
name = {}
locname ={}
Brand1 = {}
Brand2 = {}
Brand3 = {}
Brand4 = {}
Brand5 = {}
Brand6 = {}
Brand7 = {}
Brand8 = {}
Brand9 = {}
Brand10 = {}
Brand11= {}
Brand12 = {}
Brand13 = {}
Brand14 = {}
user = {}
timedf4 = {}
lat4 = {}
lng4 = {}
name4 = {}
locname4 ={}
Brand14 = {}
Brand24 = {}
Brand34 = {}
Brand44 = {}
Brand54 = {}
Brand64 = {}
Brand74 = {}
Brand84 = {}
Brand94 = {}
Brand104 = {}
Brand114= {}
Brand124 = {}
Brand134 = {}
Brand144 = {}

df = []
url = []

# %%
with requests.Session() as s:
    url = ['https://maxianetec.campodata.com/sessions','https://maxianetintl.campodata.com/sessions', 'https://maxianetpe.campodata.com/sessions', 'https://maxianetsmartmx.campodata.com/sessions','https://maxianetmex.campodata.com/sessions']
    for u in url: 
        r = s.get(u, headers=headers)
        soup = BeautifulSoup(r.content, 'html5lib')
        login_data['authenticity_token'] = soup.find('input', attrs={'name': 'authenticity_token'})['value']
        if u is 'https://maxianetintl.campodata.com/sessions':
            for weburls,weburl in zip(newvariablesIntl['ID'],newvariablesIntl['Form']):
                if weburl == 'Brand Price Audit': 
                    login_data['user[redirect_to]'] = f'{weburls}'
                    r2 = s.post(u, data=login_data,headers=headers)
                    soup2 = BeautifulSoup(r2.content, 'html5lib')
                    data  = soup2.find("script")
                    data2 = data.string
                    res = data2.partition('lat')[2]
                    reslng =data2.partition('lng')[2]
                    lat[str(weburls)] = res[2:12]
                    lng[str(weburls)] = reslng[2:12]
                    name[str(weburls)] = soup2.find('h5',{'class':'text-secondary'}).text
                    table = soup2.find('table')
                    table_rows = table.find_all('tr')
                    for tr in table_rows:
                        td = tr.find_all('td')
                        th = tr.find_all('th')
                        rowy = [i.text for i in th]
                        row = [i.text for i in td]
                        rowers = 0
                        Stone = ['Stone']
                        rowwe = 0
                        for rowie in rowy:
                            if rowie is 'Quantity of Unities in the pack':
                                rowers = rowers + 1              
                        if rowers is 0:
                            row.insert(5, "Size Unknown")
                        rowers = 0
                        df.append(row)
                    try: Brand1[str(weburls)] = df[1][0:7]
                    except Exception as exception: pass  
                    try: Brand2[str(weburls)] = df[2][0:7]
                    except Exception as exception: pass
                    try: Brand3[str(weburls)] = df[3][0:7]
                    except Exception as exception: pass
                    try: Brand4[str(weburls)] = df[4][0:7]
                    except Exception as exception: pass 
                    try: Brand5[str(weburls)] = df[5][0:7]
                    except Exception as exception: pass 
                    try: Brand6[str(weburls)] = df[6][0:7]
                    except Exception as exception: pass
                    try: Brand7[str(weburls)] = df[7][0:7]
                    except Exception as exception: pass  
                    try: Brand8[str(weburls)] = df[8][0:7]
                    except Exception as exception: pass
                    try: Brand9[str(weburls)] = df[9][0:7]
                    except Exception as exception: pass
                    try: Brand10[str(weburls)] = df[10][0:7]
                    except Exception as exception: pass 
                    try: Brand11[str(weburls)] = df[11][0:7]
                    except Exception as exception: pass 
                    try: Brand12[str(weburls)] = df[12][0:7]
                    except Exception as exception: pass
                    try: Brand13[str(weburls)] = df[13][0:7]
                    except Exception as exception: pass  
                    try: Brand14[str(weburls)] = df[14][0:7]
                    except Exception as exception: pass
                    df = []
                    timedf1 = soup2.find('input',{'class': 'form-control-plaintext bg-panel-tint pl-4 input-lg'})['value'],
                    timedf[str(weburls)] = soup2.find('input',{'class': 'form-control-plaintext bg-panel-tint pl-4 input-lg'})['value'],
                    try: locname[str(weburls)] = soup2.find('h3',{'class':'page-heading'}).text
                    except Exception as exception: pass

# %%
locnamearray = [locname]
timedfarray = [timedf]
latarray = [lat]
lngarray = [lng]
namearray = [name]
Brand1array = [Brand1][0]
Brand2array = [Brand2][0]
Brand3array = [Brand3][0]
Brand4array = [Brand4][0]
Brand5array = [Brand5][0]
Brand6array = [Brand6][0]
Brand7array = [Brand7][0]
Brand8array = [Brand8][0]
Brand9array = [Brand9][0]
Brand10array = [Brand10][0]
Brand11array = [Brand11][0]
Brand12array = [Brand12][0]
Brand13array = [Brand13][0]
Brand14array = [Brand14][0]

locnamearraydf1 = pd.DataFrame(locnamearray)
timedfarraydf1 = pd.DataFrame(timedfarray)
latarraydf1 = pd.DataFrame(latarray)
lngarraydf1 = pd.DataFrame(lngarray)
namearraydf1 = pd.DataFrame(namearray)

timedfarraydf = timedfarraydf1.T
lngarraydf = lngarraydf1.T
latarraydf = latarraydf1.T
namearraydf = namearraydf1.T
locnamearraydf = locnamearraydf1.T

# %%
Brand1array
# Out:
# {'/submissions/2620699/webview': ['Add New Brand',
#   'Bang',
#   'Lemon drop',
#   '473.0',
#   'mL',
#   'Size Unknown',
#   '1.0'],
#  '/submissions/2566744/webview': ['Add New Brand',
#   'juneshine',
#   'blood orange mint',
#   '16',
#   'OZ',
#   'Size Unknown',
#   '1'],
#  '/submissions/2566127/webview': ['Add New Brand',
#   'none of the beers on the list',
#   'none',
#   '0',
#   'mL',
#   'Size Unknown',
#   '0'],
#  '/submissions/2564847/webview': ['Add New Brand',
#   'none of the beers on the list',
#   'none',
#   '0',
#   'L',
#   'Size Unknown',
#   '0'],
#  '/submissions/2564827/webview': ['Add New Brand',
#   'stone',
#   'ipa',
#   '12',
#   'OZ',
#   'Size Unknown',
#   '12'],
#  '/submissions/2564449/webview': ['Add New Brand',
#   'mother Earth ',
#   'Cali creamin',
#   '12',
#   'OZ',
#   'Size Unknown',
#   '1'],
#  '/submissions/2564437/webview': ['Add New Brand',
#   'none of the beers on the list. February 2020',
#   'none',
#   '0',
#   'OZ',
#   'Size Unknown',
#   '0'],
#  '/submissions/2564390/webview': ['Add New Brand',
#   'bear republic',
#   'racer 5',
#   '12',
#   'OZ',
#   'Size Unknown',
#   '6'],
#  '/submissions/2564313/webview': ['Add New Brand',
#   'None of the beers in the list. February 2020',
#   'none',
#   '0.0',
#   'OZ',
#   'Size Unknown',
#   '0'],
#  '/submissions/2564305/webview': ['Add New Brand',
#   'Ballast Point',
#   'sculpin IPA',
#   '12',
#   'OZ',
#   'Size Unknown',
#   '6'],
#  '/submissions/2561470/webview': ['Add New Brand',
#   'Russian River',
#   'Happy Hops',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '1.0'],
#  '/submissions/2561445/webview': ['Add New Brand',
#   'Mother Earth',
#   'Special Release ',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '1.0'],
#  '/submissions/2561433/webview': ['Add New Brand',
#   'Julian ',
#   'Hard Cider ',
#   '22.0',
#   'OZ',
#   'Size Unknown',
#   '1.0'],
#  '/submissions/2561415/webview': ['Add New Brand',
#   'Stone',
#   'IPA',
#   '19.2',
#   'OZ',
#   'Size Unknown',
#   '1.0'],
#  '/submissions/2561394/webview': ['Stone',
#   'IPA',
#   '22.0',
#   'OZ',
#   '1.0',
#   'Size Unknown',
#   '3.99'],
#  '/submissions/2557725/webview': ['Add New Brand',
#   'Ballast point',
#   'Sculpin IPA',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '1.0'],
#  '/submissions/2557718/webview': ['Add New Brand',
#   'June Shine',
#   'Midnight Painkiller ',
#   '12.0',
#   'OZ',
#   'Size Unknown',
#   '6.0'],
#  '/submissions/2557707/webview': ['Add New Brand',
#   'AleSmith ',
#   '.394 ',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '1.0'],
#  '/submissions/2557703/webview': ['Add New Brand',
#   'Bear  Republic - bottle',
#   'Racer 5 IPA',
#   '12.0',
#   'OZ',
#   'Size Unknown',
#   '6.0'],
#  '/submissions/2557645/webview': ['Add New Brand',
#   'Mother Earth',
#   'Cali Creamin ',
#   '12.0',
#   'OZ',
#   'Size Unknown',
#   '6.0'],
#  '/submissions/2555726/webview': ['Add New Brand',
#   'June Shine',
#   'Midnight Painkiller ',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '1.0'],
#  '/submissions/2555721/webview': ['Add New Brand',
#   'Harland Brewing',
#   'Hazy IPA',
#   '12.0',
#   'OZ',
#   'Size Unknown',
#   '6.0'],
#  '/submissions/2555700/webview': ['Add New Brand',
#   'June Shine',
#   'Blood orange mint',
#   '12.0',
#   'OZ',
#   'Size Unknown',
#   '6.0'],
#  '/submissions/2555621/webview': ['Add New Brand',
#   'Bear republic',
#   'Racer 5',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '4.0'],
#  '/submissions/2550348/webview': ['Add New Brand',
#   'None of the beers on the list February 2020',
#   'none',
#   '0',
#   'mL',
#   'Size Unknown',
#   '0'],
#  '/submissions/2550334/webview': ['Add New Brand',
#   'No beers from the list February 2020',
#   'none',
#   '0',
#   'mL',
#   'Size Unknown',
#   '0'],
#  '/submissions/2550323/webview': ['Add New Brand',
#   'No beer from the list February 2020',
#   'None',
#   '0',
#   'mL',
#   'Size Unknown',
#   '0'],
#  '/submissions/2550309/webview': ['Add New Brand',
#   'stone',
#   'ipa',
#   '12',
#   'OZ',
#   'Size Unknown',
#   '11.99'],
#  '/submissions/2550294/webview': ['Add New Brand',
#   'June Shine',
#   'Blood Orange Mint',
#   '16',
#   'OZ',
#   'Size Unknown',
#   '4.99'],
#  '/submissions/2548653/webview': ['Add New Brand',
#   'Alesmith',
#   '.394',
#   '12',
#   'OZ',
#   'Size Unknown',
#   '12.99'],
#  '/submissions/2548652/webview': ['Add New Brand',
#   'Mother Earth',
#   'Cali Creamin',
#   '15',
#   'OZ',
#   'Size Unknown',
#   '2.49'],
#  '/submissions/2548651/webview': ['Add New Brand',
#   'None of the beers on the list February 2020',
#   'none',
#   '0',
#   'mL',
#   'Size Unknown',
#   '0'],
#  '/submissions/2548650/webview': ['Add New Brand',
#   'Bear Republic',
#   'Racer 5',
#   '16',
#   'OZ',
#   'Size Unknown',
#   '2.99'],
#  '/submissions/2548649/webview': ['Add New Brand',
#   'June Shine',
#   'Midnight Painkiller',
#   '12',
#   'OZ',
#   'Size Unknown',
#   '11.99'],
#  '/submissions/2548648/webview': ['Add New Brand',
#   'None of the beers on the list February 2020',
#   'None',
#   '0',
#   'mL',
#   'Size Unknown',
#   '0'],
#  '/submissions/2548647/webview': ['Add New Brand',
#   'None of the beers on the list ',
#   'none',
#   '0',
#   'mL',
#   'Size Unknown',
#   '0'],
#  '/submissions/2548645/webview': ['Add New Brand',
#   'Ale Smith',
#   '.394',
#   '16',
#   'OZ',
#   'Size Unknown',
#   '7'],
#  '/submissions/2548643/webview': ['Add New Brand',
#   'Ale Smith ',
#   'Speedway Stout',
#   '16',
#   'OZ',
#   'Size Unknown',
#   '6.99'],
#  '/submissions/2548642/webview': ['Add New Brand',
#   'None from list February 2020',
#   'None',
#   '0',
#   'mL',
#   'Size Unknown',
#   '0'],
#  '/submissions/2548638/webview': ['Add New Brand',
#   'Stone',
#   'IPA',
#   '22.0',
#   'OZ',
#   'Size Unknown',
#   '5.49'],
#  '/submissions/2548544/webview': ['Add New Brand',
#   'June Shine',
#   'Midnight Painkiller',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '5.99'],
#  '/submissions/2548529/webview': ['Add New Brand',
#   'Ale Smith ',
#   'Juice Stand ',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '7.0'],
#  '/submissions/2548514/webview': ['Add New Brand',
#   'June Shine',
#   'Midnight Painkiller',
#   '12.0',
#   'OZ',
#   'Size Unknown',
#   '2.99'],
#  '/submissions/2548490/webview': ['Add New Brand',
#   'Stone',
#   'IPA',
#   '19.2',
#   'OZ',
#   'Size Unknown',
#   '2.99'],
#  '/submissions/2548474/webview': ['Add New Brand',
#   'Bear Republic',
#   'Racer 5',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '2.99'],
#  '/submissions/2548451/webview': ['Add New Brand',
#   'Mother Earth',
#   'Cali Creamin ',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '7.0'],
#  '/submissions/2548405/webview': ['Add New Brand',
#   'Bear Republic',
#   'Racer 5 ',
#   '64.0',
#   'OZ',
#   'Size Unknown',
#   '10.99'],
#  '/submissions/2548314/webview': ['Add New Brand',
#   'Mother Earth',
#   'Cali Creamin',
#   '22.0',
#   'OZ',
#   'Size Unknown',
#   '7.99'],
#  '/submissions/2548267/webview': ['Add New Brand',
#   'Julian',
#   'Hard Apple',
#   '22.0',
#   'OZ',
#   'Size Unknown',
#   '8.99'],
#  '/submissions/2548207/webview': ['Add New Brand',
#   'Mother Earth ',
#   'Cali Creamin',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '7.0'],
#  '/submissions/2546819/webview': ['Add New Brand',
#   'Ale Smith ',
#   '.394',
#   '72.0',
#   'OZ',
#   'Size Unknown',
#   '11.99'],
#  '/submissions/2546808/webview': ['Add New Brand',
#   'Russian River',
#   'Pliny the Elder',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '7.5'],
#  '/submissions/2546791/webview': ['Add New Brand',
#   'Mother Esrth',
#   'Cali creaming ',
#   '2130.0',
#   'mL',
#   'Size Unknown',
#   '12.99'],
#  '/submissions/2546737/webview': ['Add New Brand',
#   'Oggi’s',
#   'Double Up Double IPA',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '6.5'],
#  '/submissions/2546703/webview': ['Add New Brand',
#   'Ale Smith ',
#   '394',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '7.0'],
#  '/submissions/2546649/webview': ['Add New Brand',
#   'Nova',
#   'Easy Kombucha ',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '3.99'],
#  '/submissions/2544662/webview': ['Add New Brand',
#   'Julian Hard Cider',
#   'Harvest Apple',
#   '22.0',
#   'OZ',
#   'Size Unknown',
#   '8.99'],
#  '/submissions/2542940/webview': ['Add New Brand',
#   'Ale Smith',
#   '394',
#   '12.0',
#   'OZ',
#   'Size Unknown',
#   '4.0'],
#  '/submissions/2542938/webview': ['Add New Brand',
#   'Automatic ',
#   'Kolsch and Porter',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '7.5'],
#  '/submissions/2542937/webview': ['Add New Brand',
#   'Julian ',
#   'Hard apple',
#   '22.0',
#   'OZ',
#   'Size Unknown',
#   '7.99'],
#  '/submissions/2542746/webview': ['Add New Brand',
#   'Karl Strauss',
#   'Oakwreck',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '7.5'],
#  '/submissions/2542745/webview': ['Add New Brand',
#   'Mother Earth',
#   'Cali Creamin',
#   '12.0',
#   'OZ',
#   'Size Unknown',
#   '2.25'],
#  '/submissions/2542743/webview': ['Add New Brand',
#   'Ale Smith',
#   '.394 ',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '8.0'],
#  '/submissions/2542742/webview': ['Add New Brand',
#   'Stone ',
#   'Tangerine Express',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '8.0'],
#  '/submissions/2542741/webview': ['Add New Brand',
#   'Bear Republic',
#   'Racer 5',
#   '72.0',
#   'OZ',
#   'Size Unknown',
#   '11.99'],
#  '/submissions/2542740/webview': ['Add New Brand',
#   'Bear Republic',
#   'Racer 5',
#   '72.0',
#   'OZ',
#   'Size Unknown',
#   '11.99'],
#  '/submissions/2542739/webview': ['Add New Brand',
#   'Mother Earth',
#   'Cali Creamin',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '7.5'],
#  '/submissions/2542738/webview': ['Add New Brand',
#   'Stone',
#   'Delicious ',
#   '22.0',
#   'OZ',
#   'Size Unknown',
#   '5.49'],
#  '/submissions/2542737/webview': ['Add New Brand',
#   'Mother Earth',
#   'Cali Creamin',
#   '12.0',
#   'OZ',
#   'Size Unknown',
#   '7.0'],
#  '/submissions/2542735/webview': ['Add New Brand',
#   'Mother Earth',
#   'Cali Creamin',
#   '12.0',
#   'OZ',
#   'Size Unknown',
#   '2.25'],
#  '/submissions/2542734/webview': ['Add New Brand',
#   'Karl Strauss',
#   'Mosaic IPA',
#   '12.0',
#   'OZ',
#   'Size Unknown',
#   '1.8'],
#  '/submissions/2542720/webview': ['Tonica Antartica',
#   'Guarana Reg or diet ',
#   '12.0',
#   'OZ',
#   '3.25',
#   'Size Unknown'],
#  '/submissions/2540774/webview': ['Stone',
#   'Made west',
#   '16.0',
#   'OZ',
#   '7.5',
#   'Size Unknown'],
#  '/submissions/2540773/webview': ['Add New Brand',
#   'Ballast point',
#   'Sculpin IPA draught',
#   '16.0',
#   'OZ',
#   'Size Unknown',
#   '6.95']}

# %%
for row in Brand1array:
    row = False
    for rowy in Brand1array[row]:
        if rowy == 'Add New Brand':
            row = True
            if row
# Out:
# /submissions/2620699/webview
# /submissions/2566744/webview
# /submissions/2566127/webview
# /submissions/2564847/webview
# /submissions/2564827/webview
# /submissions/2564449/webview
# /submissions/2564437/webview
# /submissions/2564390/webview
# /submissions/2564313/webview
# /submissions/2564305/webview
# /submissions/2561470/webview
# /submissions/2561445/webview
# /submissions/2561433/webview
# /submissions/2561415/webview
# /submissions/2557725/webview
# /submissions/2557718/webview
# /submissions/2557707/webview
# /submissions/2557703/webview
# /submissions/2557645/webview
# /submissions/2555726/webview
# /submissions/2555721/webview
# /submissions/2555700/webview
# /submissions/2555621/webview
# /submissions/2550348/webview
# /submissions/2550334/webview
# /submissions/2550323/webview
# /submissions/2550309/webview
# /submissions/2550294/webview
# /submissions/2548653/webview
# /submissions/2548652/webview
# /submissions/2548651/webview
# /submissions/2548650/webview
# /submissions/2548649/webview
# /submissions/2548648/webview
# /submissions/2548647/webview
# /submissions/2548645/webview
# /submissions/2548643/webview
# /submissions/2548642/webview
# /submissions/2548638/webview
# /submissions/2548544/webview
# /submissions/2548529/webview
# /submissions/2548514/webview
# /submissions/2548490/webview
# /submissions/2548474/webview
# /submissions/2548451/webview
# /submissions/2548405/webview
# /submissions/2548314/webview
# /submissions/2548267/webview
# /submissions/2548207/webview
# /submissions/2546819/webview
# /submissions/2546808/webview
# /submissions/2546791/webview
# /submissions/2546737/webview
# /submissions/2546703/webview
# /submissions/2546649/webview
# /submissions/2544662/webview
# /submissions/2542940/webview
# /submissions/2542938/webview
# /submissions/2542937/webview
# /submissions/2542746/webview
# /submissions/2542745/webview
# /submissions/2542743/webview
# /submissions/2542742/webview
# /submissions/2542741/webview
# /submissions/2542740/webview
# /submissions/2542739/webview
# /submissions/2542738/webview
# /submissions/2542737/webview
# /submissions/2542735/webview
# /submissions/2542734/webview
# /submissions/2540773/webview
